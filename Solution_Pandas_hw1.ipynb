# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Basic info
#
# Read the data-file (a 10 000 row subset of most rated IMDB-movies) into Pandas DataFrame and name the DataFrame-variable to `df` (use tab-character (`\t`) as the separator)
#
# 1. Use the following column-names: `ID, title, year, rating, votes, duration, genres`
# 2. Index the `df` with `ID`-column (either on reading the file or after it.)
# 3. Display first 5 rows of the `df`
# 4. Display last 11 rows of the `df`
# 5. Display the `df`-info

# %% [markdown]
# ### created dataframe df with movie_data.txt file with column names

# %%
df= pd.read_csv('movie_data.txt', sep="\t", header=None)
df.columns = ["ID", "title", "year", "rating","votes","duration","genres"]
df
# Out:
#              ID                                              title  year  \
# 0     tt0111161                    The Shawshank Redemption (1994)  1994
# 1     tt0110912                                Pulp Fiction (1994)  1994
# 2     tt0137523                                  Fight Club (1999)  1999
# 3     tt0133093                                  The Matrix (1999)  1999
# 4     tt1375666                                   Inception (2010)  2010
# 5     tt0109830                                Forrest Gump (1994)  1994
# 6     tt0169547                             American Beauty (1999)  1999
# 7     tt0499549                                      Avatar (2009)  2009
# 8     tt0108052                            Schindler's List (1993)  1993
# 9     tt0080684  Star Wars: Episode V - The Empire Strikes Back...  1980
# 10    tt0372784                               Batman Begins (2005)  2005
# 11    tt0114814                          The Usual Suspects (1995)  1995
# ...

# %% [markdown]
# ### Index the `df` with `ID`-column (either on reading the file or after it.)

# %%
df.set_index("ID",inplace=True)
df.head()
# Out:
#                                      title  year  rating   votes   duration  \
# ID
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
#
#                                      genres
# ID
# tt0111161                       Crime|Drama
# tt0110912                    Crime|Thriller
# tt0137523            Drama|Mystery|Thriller
# tt0133093           Action|Adventure|Sci-Fi
# tt1375666  Action|Adventure|Sci-Fi|Thriller

# %% [markdown]
# ### Display first 5 rows of the `df`

# %%
df.head(5)
# Out:
#                                      title  year  rating   votes   duration  \
# ID
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479  142 mins.
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065  154 mins.
# tt0137523                Fight Club (1999)  1999     8.8  458173  139 mins.
# tt0133093                The Matrix (1999)  1999     8.7  448114  136 mins.
# tt1375666                 Inception (2010)  2010     8.9  385149  148 mins.
#
#                                      genres
# ID
# tt0111161                       Crime|Drama
# tt0110912                    Crime|Thriller
# tt0137523            Drama|Mystery|Thriller
# tt0133093           Action|Adventure|Sci-Fi
# tt1375666  Action|Adventure|Sci-Fi|Thriller

# %% [markdown]
# ### Display last 11 rows of the `df`

# %%
df.tail(11)
# Out:
#                                          title  year  rating  votes  \
# ID
# tt0101356                   Another You (1991)  1991     4.9   1359
# tt0421090                    Zerophilia (2005)  2005     6.3   1359
# tt0067227  The Merchant of Four Seasons (1971)  1971     7.6   1359
# tt0339727                     Stateside (2004)  2004     5.8   1358
# tt0218581                  Scarlet Diva (2000)  2000     5.2   1358
# tt0118635                        Aprile (1998)  1998     6.7   1358
# tt0807721                       Meduzot (2007)  2007     7.0   1357
# tt0339642                Daltry Calhoun (2005)  2005     5.2   1357
# tt0060880        The Quiller Memorandum (1966)  1966     6.5   1356
# tt0152836                          Taal (1999)  1999     6.5   1356
# tt0279977                The Navigators (2001)  2001     6.9   1356
#
#             duration                      genres
# ID
# tt0101356   98 mins.                Comedy|Crime
# ...

# %% [markdown]
# ### Display the `df`-info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, tt0111161 to tt0279977
# Data columns (total 6 columns):
# title       10000 non-null object
# year        10000 non-null int64
# rating      10000 non-null float64
# votes       10000 non-null int64
# duration    10000 non-null object
# genres      9999 non-null object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 390.6+ KB

# %% [markdown]
# ## Cleaning

# %% [markdown]
# ### Drop all the missing rows which contain any column with missing data

# %%
df.dropna()
# Out:
#                                                        title  year  rating  \
# ID
# tt0111161                    The Shawshank Redemption (1994)  1994     9.2
# tt0110912                                Pulp Fiction (1994)  1994     9.0
# tt0137523                                  Fight Club (1999)  1999     8.8
# tt0133093                                  The Matrix (1999)  1999     8.7
# tt1375666                                   Inception (2010)  2010     8.9
# tt0109830                                Forrest Gump (1994)  1994     8.7
# tt0169547                             American Beauty (1999)  1999     8.6
# tt0499549                                      Avatar (2009)  2009     8.1
# tt0108052                            Schindler's List (1993)  1993     8.9
# tt0080684  Star Wars: Episode V - The Empire Strikes Back...  1980     8.8
# tt0372784                               Batman Begins (2005)  2005     8.3
# ...

# %%
df1 = df['duration'].str.split(' mins.', expand=True)
df['duration']=(df1[0].astype(int))*60
df.head()
# Out:
#                                      title  year  rating   votes  duration  \
# ID
# tt0111161  The Shawshank Redemption (1994)  1994     9.2  619479      8520
# tt0110912              Pulp Fiction (1994)  1994     9.0  490065      9240
# tt0137523                Fight Club (1999)  1999     8.8  458173      8340
# tt0133093                The Matrix (1999)  1999     8.7  448114      8160
# tt1375666                 Inception (2010)  2010     8.9  385149      8880
#
#                                      genres
# ID
# tt0111161                       Crime|Drama
# tt0110912                    Crime|Thriller
# tt0137523            Drama|Mystery|Thriller
# tt0133093           Action|Adventure|Sci-Fi
# tt1375666  Action|Adventure|Sci-Fi|Thriller

# %%
s=pd.Series(df['title'])
df['subtitle']=s.map(lambda a: a[:-6])
df['title']=df['subtitle']
df.head()
# Out:
#                          title  year  rating   votes  duration  \
# ID
# tt0111161  The Shawshank Redem  1994     9.2  619479      8520
# tt0110912              Pulp Fi  1994     9.0  490065      9240
# tt0137523                Fight  1999     8.8  458173      8340
# tt0133093                The M  1999     8.7  448114      8160
# tt1375666                 Ince  2010     8.9  385149      8880
#
#                                      genres             subtitle
# ID
# tt0111161                       Crime|Drama  The Shawshank Redem
# tt0110912                    Crime|Thriller              Pulp Fi
# tt0137523            Drama|Mystery|Thriller                Fight
# tt0133093           Action|Adventure|Sci-Fi                The M
# tt1375666  Action|Adventure|Sci-Fi|Thriller                 Ince

# %%
df=df.drop(columns='subtitle')
df.head()
# Out:
#                                title  year  rating   votes  duration  \
# ID
# tt0111161  The Shawshank Redemption   1994     9.2  619479      8520
# tt0110912              Pulp Fiction   1994     9.0  490065      9240
# tt0137523                Fight Club   1999     8.8  458173      8340
# tt0133093                The Matrix   1999     8.7  448114      8160
# tt1375666                 Inception   2010     8.9  385149      8880
#
#                                      genres
# ID
# tt0111161                       Crime|Drama
# tt0110912                    Crime|Thriller
# tt0137523            Drama|Mystery|Thriller
# tt0133093           Action|Adventure|Sci-Fi
# tt1375666  Action|Adventure|Sci-Fi|Thriller

# %% [markdown]
# ## Concatenating

# %% [markdown]
# ### Read crew_data.tsv.gz to DataFrame named movie_crew_df with columns ID, director_ids indexed by ID (forget the rest of the columns)

# %%
movie_crew_df= pd.read_csv('crew_data.tsv', sep="\t", header=None)
movie_crew_df.columns = ["ID", "director_ids","writers"]
movie_crew_df=movie_crew_df.set_index("ID")
movie_crew_df.head()
# Out:
#           ID director_ids  writers
# 0     tconst    directors  writers
# 1  tt0000001    nm0005690       \N
# 2  tt0000002    nm0721526       \N
# 3  tt0000003    nm0721526       \N
# 4  tt0000004    nm0721526       \N

# %%
movie_crew_df=movie_crew_df["director_ids"]
movie_crew_df.head()
# Out:
# ID
# tconst       directors
# tt0000001    nm0005690
# tt0000002    nm0721526
# tt0000003    nm0721526
# tt0000004    nm0721526
# Name: director_ids, dtype: object

# %% [markdown]
# ### Read person_data.tsv.gz to DataFrame named person_df with columns person_ID, name indexed by person_ID

# %%
person_df= pd.read_csv("name_data.tsv",sep='\t',header=None)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-3-443e436c7645> in <module>
# ----> 1 person_df= pd.read_csv("name_data.tsv",sep='\t',header=None)
#
# c:\users\user\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...
