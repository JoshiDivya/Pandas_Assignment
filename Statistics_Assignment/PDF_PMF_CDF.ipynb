# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# ## PMF (probability mass function)

# %%
xk = np.arange(7)
pk = (0.1, 0.2, 0.3, 0.1, 0.1, 0.0, 0.2)
custm = stats.rv_discrete(name='custm', values=(xk, pk))

fig, ax = plt.subplots(1, 1)
ax.plot(xk, custm.pmf(xk), 'ro', ms=8, mec='r')
ax.vlines(xk, 0, custm.pmf(xk), colors='r', linestyles='-', lw=2)
plt.title('Custom made discrete distribution(PMF)')
plt.ylabel('Probability')
plt.show()

# %%
import pandas as pd

# %%
from collections import Counter

# %% [markdown]
# * converted series data to dictionary key and value pairs *

# %%
def pmf(series):
    n = len(series)
    d = {}
    counts = Counter(series)
    for _, key in enumerate(counts):
        d[key] = counts[key]/n
    return d

# %% [markdown]
# ** In CDF, probability of any sample data is the probability of the previous data added to the current data probability

# %%
def cdf(series):
    sorted_s =  series.sort_values(ascending=True)
    pmf_dict = pmf(sorted_s)
    cumsum = 0
    sums = []
    for x,value in pmf_dict.items():
        cumsum += value
        sums.append(cumsum)
    return sums

# %%
pmf_first = pd.Series(pmf([1, 2, 2, 3, 5]))
pmf_first.sort_index().plot(kind='bar')

# %%
## CDF (cumulative distribution function)

# %%
cdf_first=pd.Series([1, 2, 2, 3, 5])
cdf_first.hist(cumulative=True, density=0, bins=100)

# %%
cdf_sums = cdf(cdf_first)
plt.plot(cdf_sums)

# %%
from pylab import *

x = linspace(0.1, 2*pi, 10)
markerline, stemlines, baseline = stem(x, cos(x), '-.')
setp(markerline, 'markerfacecolor', 'b')
setp(baseline, 'color','r', 'linewidth', 2)

show()
